# %% [markdown]
# # Task 3: Classification Using Decision Tree Classifier on famous Iris dataset

# %% [markdown]
# ## Importing Relevant Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Loading the dataset

# %%
data=pd.read_csv('iris.csv')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.shape
# Out:
# (150, 6)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Finding the missing values in dataset

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ### Note: No Missing values hence dataset is fully complete so we will move forward for eliminating irrelevant features

# %% [markdown]
# ### Note: Removing the 'ID' column will not affect the data but if we don't remove it, chances are there that it may capture some noise and can predict wrongly

# %%
data.drop('Id', axis=1 , inplace=True)

# %%
corelation=data.corr()
sns.heatmap(corelation)
# Out:
# <AxesSubplot:>

# %%
data.describe(include='all')
# Out:
#         SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count      150.000000    150.000000     150.000000    150.000000
# unique            NaN           NaN            NaN           NaN
# top               NaN           NaN            NaN           NaN
# freq              NaN           NaN            NaN           NaN
# mean         5.843333      3.054000       3.758667      1.198667
# std          0.828066      0.433594       1.764420      0.763161
# min          4.300000      2.000000       1.000000      0.100000
# 25%          5.100000      2.800000       1.600000      0.300000
# 50%          5.800000      3.000000       4.350000      1.300000
# 75%          6.400000      3.300000       5.100000      1.800000
# max          7.900000      4.400000       6.900000      2.500000
#
#                Species
# count              150
# unique               3
# top     Iris-virginica
# freq                50
# mean               NaN
# std                NaN
# ...

# %% [markdown]
# ### Note: Here we can see that frequency of species occuring the most is 'Iris-Virginica' which is 50 and also the mean length and width of sepal and petal also gives us the idea about the density of data

# %%
plt.figure(figsize=(14,6))
sns.countplot('SepalLengthCm',data=data)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='count'>

# %%
plt.figure(figsize=(14,6))
sns.distplot(data.SepalLengthCm, bins=10)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm'>

# %% [markdown]
# ###  Here we can see that the data is mostly situated in range from 4.5 to 6.5

# %%
plt.figure(figsize=(14,6))
sns.countplot('SepalWidthCm', data=data)
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='count'>

# %%
plt.figure(figsize=(14,6))
sns.distplot(data.SepalWidthCm, bins=10)
# Out:
# <AxesSubplot:xlabel='SepalWidthCm'>

# %% [markdown]
# ### Here we can see that the data is mostly distributed in range 2.5 to 3.5

# %%
plt.figure(figsize=(14,6))
sns.countplot('PetalLengthCm', data=data)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='count'>

# %%
plt.figure(figsize=(14,6))
sns.distplot(data.PetalLengthCm, bins=10)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm'>

# %%
plt.figure(figsize=(14,6))
sns.countplot('PetalWidthCm', data=data)
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='count'>

# %%
plt.figure(figsize=(14,6))
sns.distplot(data.PetalWidthCm, bins=6)
# Out:
# <AxesSubplot:xlabel='PetalWidthCm'>

# %%
plt.figure(figsize=(14,6))
sns.scatterplot(x=data.PetalLengthCm, y=data.SepalLengthCm, cmap='cool', color='black')
plt.xlabel('Petal Length', fontsize=16)
plt.ylabel('Sepal Length', fontsize=16)
plt.title(' Petal Length va Sepal Length', fontsize=16)
# Out:
# Text(0.5, 1.0, ' Petal Length va Sepal Length')

# %%
plt.figure(figsize=(14,6))
sns.scatterplot(x=data.PetalWidthCm, y=data.SepalWidthCm, cmap='cool', color='black')
plt.xlabel('Petal Width', fontsize=16)
plt.ylabel('Sepal Width', fontsize=16)
plt.title(' Petal Width va Sepal Widthth', fontsize=16)
# Out:
# Text(0.5, 1.0, ' Petal Width va Sepal Widthth')

# %%
plt.figure(figsize=(14,6))
sns.scatterplot(x=data.PetalLengthCm, y=data.SepalWidthCm, cmap='cool', color='black')
plt.xlabel('Petal Length', fontsize=16)
plt.ylabel('Sepal Width', fontsize=16)
plt.title(' Petal Length va Sepal Width', fontsize=16)
# Out:
# Text(0.5, 1.0, ' Petal Length va Sepal Width')

# %%
plt.figure(figsize=(14,6))
sns.scatterplot(x=data.PetalWidthCm, y=data.SepalLengthCm, cmap='cool', color='black')
plt.xlabel('Petal Width', fontsize=16)
plt.ylabel('Sepal Length', fontsize=16)
plt.title(' Petal Width va Sepal Length', fontsize=16)
# Out:
# Text(0.5, 1.0, ' Petal Width va Sepal Length')

# %% [markdown]
# ### Let us see all the above graphs in one graph so to get complete view

# %%
sns.pairplot(data, hue='Species')

# %% [markdown]
# ## Targets and variables

# %%
X=data.iloc[:,[0,1,2,3]].values
y=data.iloc[:,[4]].values

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
y
# Out:
# array([['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier(criterion='entropy')

# %%
clf=model.fit(X,y)

# %%
from sklearn import tree

# %%
plt.figure(figsize=(15,10), facecolor='k')
tree.plot_tree(model,feature_names=data.columns,filled=True)
# Out:
# [Text(418.5, 498.3, 'PetalWidthCm <= 0.8\nentropy = 1.585\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(354.11538461538464, 407.70000000000005, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(482.8846153846154, 407.70000000000005, 'PetalWidthCm <= 1.75\nentropy = 1.0\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(257.53846153846155, 317.1, 'PetalLengthCm <= 4.95\nentropy = 0.445\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(128.76923076923077, 226.5, 'PetalWidthCm <= 1.65\nentropy = 0.146\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(64.38461538461539, 135.89999999999998, 'entropy = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(193.15384615384616, 135.89999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(386.3076923076923, 226.5, 'PetalWidthCm <= 1.55\nentropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(321.9230769230769, 135.89999999999998, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
# ...

# %% [markdown]
# ## Note: The basic principle of branching is based on calculation of entropy and information gain. Thus higher values of these will give give us the point to branch
